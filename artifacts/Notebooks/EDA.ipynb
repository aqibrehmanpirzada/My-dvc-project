# %%
import pandas as pd

# URL to the CSV file
csv_url = "https://data-set-mine.s3.us-west-2.amazonaws.com/world-data-2023.csv"

# Load the data into a pandas DataFrame
df = pd.read_csv(csv_url)

# Now you can work with the df DataFrame as needed

# %%
import numpy as np

# %%
# !pwd
# Out:
# /media/aqib/Software/MLOPS Project/Project 1/My-dvc-project/artifacts/Notebooks

# %%
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# ...

# %%
import os
import urllib.request

# URL to the CSV file
csv_url = "https://data-set-mine.s3.us-west-2.amazonaws.com/world-data-2023.csv"

# Get the current directory of the notebook
notebook_dir = os.path.abspath('')

# Local path to save the downloaded file in the current directory
local_file_path = os.path.join(notebook_dir, "world-data-2023.csv")

# Download the file from the URL and save it locally
urllib.request.urlretrieve(csv_url, local_file_path)

print("File downloaded and saved in the current directory:", local_file_path)
# Out:
# File downloaded and saved in the current directory: /media/aqib/Software/MLOPS Project/Project 1/My-dvc-project/artifacts/Notebooks/world-data-2023.csv

# %%
df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    195 non-null    object
#  1   Density
# (P/Km2)                            195 non-null    object
#  2   Abbreviation                               188 non-null    object
#  3   Agricultural Land( %)                      188 non-null    object
#  4   Land Area(Km2)                             194 non-null    object
#  5   Armed Forces size                          171 non-null    object
#  6   Birth Rate                                 189 non-null    float64
#  7   Calling Code                               194 non-null    float64
#  8   Capital/Major City                         192 non-null    object
#  9   Co2-Emissions                              188 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Country                                       0
# Density\n(P/Km2)                              0
# Abbreviation                                  7
# Agricultural Land( %)                         7
# Land Area(Km2)                                1
# Armed Forces size                            24
# Birth Rate                                    6
# Calling Code                                  1
# Capital/Major City                            3
# Co2-Emissions                                 7
# CPI                                          17
# CPI Change (%)                               16
# Currency-Code                                15
# Fertility Rate                                7
# Forested Area (%)                             7
# Gasoline Price                               20
# GDP                                           2
# Gross primary education enrollment (%)        7
# Gross tertiary education enrollment (%)      12
# Infant mortality                              6
# ...

# %%
df.shape
# Out:
# (195, 35)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                                      0
# Density\n(P/Km2)                             0
# Abbreviation                                 0
# Agricultural Land( %)                        0
# Land Area(Km2)                               0
# Armed Forces size                            0
# Birth Rate                                   0
# Calling Code                                 0
# Capital/Major City                           0
# Co2-Emissions                                0
# CPI                                          0
# CPI Change (%)                               0
# Currency-Code                                0
# Fertility Rate                               0
# Forested Area (%)                            0
# Gasoline Price                               0
# GDP                                          0
# Gross primary education enrollment (%)       0
# Gross tertiary education enrollment (%)      0
# Infant mortality                             0
# ...

# %%
# import plotly.express as px

# %%
data = df.copy()

# %% [markdown]
# #### Exploratory Data Analysis (EDA) is an important step in understanding and summarizing the main characteristics of your dataset. Given your dataset with various columns, here are the steps you can take for EDA:
#
# 1. Data Cleaning:
#
# Check for missing values in each column and decide how to handle them. You might need to impute missing values or remove rows/columns with too many missing values.
# Convert data types to appropriate formats. For example, convert object types to numerical formats where applicable.
# Remove any duplicate rows if present.
#
# 2. Summary Statistics:
#
# Calculate summary statistics such as mean, median, standard deviation, minimum, and maximum for numerical columns.
# For categorical columns, find unique values and their frequencies.
#
# 3. Data Visualization:
#
# Create visualizations to understand the distribution of numerical variables using histograms, box plots, and density plots.
# For categorical variables, create bar plots to visualize the frequency of each category.
# Plot correlations between numerical variables using scatter plots or correlation matrices.
# Geographical data like latitude and longitude can be visualized on a map.
#
# 4. Handling Outliers:
#
# Identify and handle outliers in your numerical data. Outliers can significantly impact statistical analysis and modeling.
# 5. Feature Relationships:
#
# Explore how different numerical and categorical variables are related to each other.
# Check for any patterns or trends that might reveal interesting insights.
# 6. Data Distributions:
#
# Analyze the distributions of variables. Check if they follow normal distributions or if they have skewed distributions.
# 7. Handling Categorical Variables:
#
# Explore the distribution of categories within categorical variables.
# Consider using bar plots or pie charts to visualize categorical distributions.
#
# 8. Data Transformation:
#
# If necessary, transform variables to make their distributions more normal. Common transformations include logarithmic or power transformations.
#
# 9. Correlation Analysis:
#
# Calculate and visualize correlations between numerical variables using correlation matrices or heatmaps.
# Identify strong correlations that might indicate relationships between variables.
#
# 9. Domain-Specific Analysis:
#
# If you have domain-specific knowledge, use it to guide your exploration. For example, if your dataset is related to economics, you might focus on variables like GDP, tax rates, and unemployment.
#
# 10. Missing Data Analysis:
#
# Analyze the patterns of missing data. Are the missing values random or do they follow a pattern? This can provide insights into data collection processes.
#
# 11. Statistical Tests (Optional):
#
# Perform statistical tests to assess hypotheses or relationships between variables, if applicable.
# Remember that EDA is a flexible process, and the steps you take can vary based on the nature of your dataset and the insights you're seeking to gain. Visualization tools like matplotlib, seaborn, and pandas in Python can be incredibly helpful for conducting these analyses.

# %%
data = df.copy()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Data Cleaning
# Handle missing values
data.dropna(subset=['Country'], inplace=True)  # Drop rows with missing country names
data['Density\n(P/Km2)'] = data['Density\n(P/Km2)'].str.replace(',', '').astype(float)  # Convert to float
# Handle other columns similarly...

# %%
# 2. Summary Statistics
summary_stats = data.describe()
print(summary_stats)
# Out:
#        Density\n(P/Km2)  Birth Rate  Calling Code  Fertility Rate  \
# count        110.000000  110.000000    110.000000      110.000000
# mean         148.454545   20.196455    344.290909        2.672182
# std          210.855211   10.039056    341.231562        1.308142
# min            2.000000    6.400000      1.000000        0.980000
# 25%           34.500000   11.075000     70.000000        1.682500
# 50%           89.000000   17.830000    239.500000        2.200000
# 75%          151.750000   27.962500    420.750000        3.505000
# max         1380.000000   46.080000   1876.000000        6.910000
#
#        Infant mortality  Life expectancy  Maternal mortality ratio  \
# count        110.000000       110.000000                110.000000
# mean          20.271818        72.671818                137.227273
# std           18.453214         7.000788                201.171462
# min            1.700000        54.300000                  2.000000
# ...

# %%
data.GDP
# Out:
# 0          $19,101,353,833
# 1          $15,278,077,447
# 2         $169,988,236,398
# 4          $94,635,415,870
# 6         $449,663,446,954
#                ...
# 185     $2,827,113,184,696
# 186    $21,427,700,000,000
# 187        $56,045,912,952
# 191       $261,921,244,843
# 193        $23,064,722,446
# Name: GDP, Length: 110, dtype: object

# %%
data['GDP'] = data['GDP'].str.replace('$', '').str.replace(',', '').astype(float)
# Out:
# /tmp/ipykernel_94256/3780895833.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['GDP'] = data['GDP'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
# 3. Data Visualization
plt.figure(figsize=(10, 6))
plt.hist(data['Density\n(P/Km2)'])
plt.title('Density Distribution')
plt.xlabel('Density')
plt.ylabel('Frequency')
plt.show()

sns.barplot(x='Country', y='GDP', data=data.head(10))
plt.xticks(rotation=90)
plt.title('Top 10 Countries by GDP')
plt.xlabel('Country')
plt.ylabel('GDP')
plt.show()

# %%
df.head(2)
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# 1             Tirana         4,536  ...                           56.90%
#
#   Physicians per thousand  Population  \
# 0                    0.28  38,041,754
# 1                    1.20   2,854,191
#
#    Population: Labor force participation (%) Tax revenue (%) Total tax rate  \
# 0                                     48.90%           9.30%         71.40%
# 1                                     55.70%          18.60%         36.60%
#
# ...

# %%
# 4. Handling Outliers (Example: Using Z-Score)
from scipy.stats import zscore
data['GDP_zscore'] = zscore(data['GDP'])
data_without_outliers = data[(data['GDP_zscore'] > -3) & (data['GDP_zscore'] < 3)]
data_without_outliers.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude', 'GDP_zscore'],
#       dtype='object')

# %%
# 5. Feature Relationships
sns.pairplot(data_without_outliers[['GDP', 'Birth Rate', 'Life expectancy','Abbreviation']],hue='Abbreviation')
plt.show()

# %%
for column in data_without_outliers.columns:
    if data_without_outliers[column].dtype in ['int64', 'float64']:
        sns.distplot(data_without_outliers[column])
        plt.title(f'{column} Distribution')
        plt.show()
# Out:
# /tmp/ipykernel_94256/1779455157.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_without_outliers[column])
# /tmp/ipykernel_94256/1779455157.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_without_outliers[column])
# ...

# %%
# 7. Handling Categorical Variables
plt.figure(figsize=(10, 6))
sns.countplot(x='Official language', data=data_without_outliers)
plt.xticks(rotation=90)
plt.title('Official Languages Count Accross the Countries')
plt.xlabel('Official Language')
plt.ylabel('Count')
plt.show()

# %%
# 8. Data Transformation
data['Log_GDP'] = np.log(data['GDP'])
sns.distplot(data['Log_GDP'])
plt.title('Log Transformed GDP Distribution')
plt.show()
# Out:
# /tmp/ipykernel_94256/2446907096.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Log_GDP'])

# %%
plt.figure(figsize=(20,10))
# 9. Correlation Analysis
correlation_matrix = data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='magma')
plt.title('Correlation Matrix')
plt.show()
# Out:
# /tmp/ipykernel_94256/79597656.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
# 10. Domain-Specific Analysis
sns.scatterplot(x='Unemployment rate', y='GDP', data=data_without_outliers)
plt.title('Unemployment Rate vs. GDP')
plt.xlabel('Unemployment Rate')
plt.ylabel('GDP')
plt.show()

# %%
# 11. Missing Data Analysis
missing_data_percentage = data.isnull().mean() * 100
print(missing_data_percentage)
# Out:
# Country                                      0.0
# Density\n(P/Km2)                             0.0
# Abbreviation                                 0.0
# Agricultural Land( %)                        0.0
# Land Area(Km2)                               0.0
# Armed Forces size                            0.0
# Birth Rate                                   0.0
# Calling Code                                 0.0
# Capital/Major City                           0.0
# Co2-Emissions                                0.0
# CPI                                          0.0
# CPI Change (%)                               0.0
# Currency-Code                                0.0
# Fertility Rate                               0.0
# Forested Area (%)                            0.0
# Gasoline Price                               0.0
# GDP                                          0.0
# Gross primary education enrollment (%)       0.0
# Gross tertiary education enrollment (%)      0.0
# ...

# %%
# 12. Statistical Tests (Example: T-test)
from scipy.stats import ttest_ind
group1 = data_without_outliers[data_without_outliers['Country'] == 'Country1']['GDP']
group2 = data_without_outliers[data_without_outliers['Country'] == 'Country2']['GDP']
t_statistic, p_value = ttest_ind(group1, group2)
print(f"T-statistic: {t_statistic}, p-value: {p_value}")
# Out:
# T-statistic: nan, p-value: nan

# %% [markdown]
# ### Data Preprocessing

# %%
data_without_outliers.head()
# Out:
#        Country  Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan              60.0           AF                58.10%
# 1      Albania             105.0           AL                43.10%
# 2      Algeria              18.0           DZ                17.40%
# 4       Angola              26.0           AO                47.50%
# 6    Argentina              17.0           AR                54.30%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 4      1,246,700           117,000       40.73         244.0
# 6      2,780,400           105,000       17.02          54.0
#
#   Capital/Major City Co2-Emissions  ... Physicians per thousand  Population  \
# 0              Kabul         8,672  ...                    0.28  38,041,754
# ...

# %%
data_without_outliers.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude', 'GDP_zscore'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude', 'GDP_zscore', 'Log_GDP'],
#       dtype='object')

# %%
def separate_categorical_numerical(data_frame):
    categorical_columns = []
    numerical_columns = []

    for column in data_frame.columns:
        if pd.api.types.is_categorical_dtype(data_frame[column]):
            categorical_columns.append(column)
        elif pd.api.types.is_numeric_dtype(data_frame[column]):
            numerical_columns.append(column)

    return categorical_columns, numerical_columns

# %%
import pandas as pd

def separate_object_numerical(data_frame):
    object_columns = []
    numerical_columns = []

    for column in data_frame.columns:
        if data_frame[column].dtype == 'object':
            object_columns.append(column)
        elif pd.api.types.is_numeric_dtype(data_frame[column]):
            numerical_columns.append(column)

    return object_columns, numerical_columns

# %%
object_cols, numerical_cols = separate_object_numerical(data)
print("Object Columns:", object_cols)
print("Numerical Columns:", numerical_cols)
# Out:
# Object Columns: ['Country', 'Abbreviation', 'Agricultural Land( %)', 'Land Area(Km2)', 'Armed Forces size', 'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)', 'Currency-Code', 'Forested Area (%)', 'Gasoline Price', 'Gross primary education enrollment (%)', 'Gross tertiary education enrollment (%)', 'Largest city', 'Minimum wage', 'Official language', 'Out of pocket health expenditure', 'Population', 'Population: Labor force participation (%)', 'Tax revenue (%)', 'Total tax rate', 'Unemployment rate', 'Urban_population']
# Numerical Columns: ['Density\n(P/Km2)', 'Birth Rate', 'Calling Code', 'Fertility Rate', 'GDP', 'Infant mortality', 'Life expectancy', 'Maternal mortality ratio', 'Physicians per thousand', 'Latitude', 'Longitude', 'GDP_zscore', 'Log_GDP']

# %%
data[object_cols]
# Out:
#             Country Abbreviation Agricultural Land( %) Land Area(Km2)  \
# 0       Afghanistan           AF                58.10%        652,230
# 1           Albania           AL                43.10%         28,748
# 2           Algeria           DZ                17.40%      2,381,741
# 4            Angola           AO                47.50%      1,246,700
# 6         Argentina           AR                54.30%      2,780,400
# ..              ...          ...                   ...            ...
# 185  United Kingdom           GB                71.70%        243,610
# 186   United States           US                44.40%      9,833,517
# 187         Uruguay           UY                82.60%        176,215
# 191         Vietnam           VN                39.30%        331,210
# 193          Zambia           ZM                32.10%        752,618
#
#     Armed Forces size Capital/Major City Co2-Emissions     CPI CPI Change (%)  \
# ...

# %%
def clean_percentage_column(column):
    cleaned_values = []

    for value in column:
        if isinstance(value, str):
            value = value.strip('%')  # Remove percentage symbol
            if value.replace('.', '', 1).isdigit():  # Check if value is numeric after removing first period
                cleaned_values.append(float(value))
            else:
                cleaned_values.append(np.nan)
        else:
            cleaned_values.append(value)

    return cleaned_values

# Apply the function to each percentage column separately
data['Agricultural Land( %)'] = clean_percentage_column(data['Agricultural Land( %)'])
data['CPI Change (%)'] = clean_percentage_column(data['CPI Change (%)'])
data['Minimum wage'] = clean_percentage_column(data['Minimum wage'])
data['Out of pocket health expenditure'] = clean_percentage_column(data['Out of pocket health expenditure'])
data['Population: Labor force participation (%)'] = clean_percentage_column(data['Population: Labor force participation (%)'])
data['Tax revenue (%)'] = clean_percentage_column(data['Tax revenue (%)'])
data['Total tax rate'] = clean_percentage_column(data['Total tax rate'])
data['Unemployment rate'] = clean_percentage_column(data['Unemployment rate'])
data['Forested Area (%)'] = clean_percentage_column(data['Forested Area (%)'])
data['Gross primary education enrollment (%)'] = clean_percentage_column(data['Gross primary education enrollment (%)'])
data['Gross tertiary education enrollment (%)'] = clean_percentage_column(data['Gross tertiary education enrollment (%)'])

# %%
import numpy as np

def clean_comma_numeric_column(column):
    cleaned_values = []

    for value in column:
        if isinstance(value, str):
            cleaned_value = value.replace(',', '')  # Remove commas
            if cleaned_value.replace('.', '', 1).isdigit():  # Check if value is numeric after removing first period
                cleaned_values.append(int(cleaned_value))
            else:
                cleaned_values.append(np.nan)
        else:
            cleaned_values.append(value)

    return cleaned_values

# Apply the function to each column separately
data['Land Area(Km2)'] = clean_comma_numeric_column(data['Land Area(Km2)'])
data['Co2-Emissions'] = clean_comma_numeric_column(data['Co2-Emissions'])
data['Urban_population'] = clean_comma_numeric_column(data['Urban_population'])

# %%
data['Armed Forces size'] = clean_comma_numeric_column(data['Armed Forces size'])
data['Population'] = clean_comma_numeric_column(data['Population'])

# %%
data.head(3)
# Out:
#        Country  Density\n(P/Km2) Abbreviation  Agricultural Land( %)  \
# 0  Afghanistan              60.0           AF                   58.1
# 1      Albania             105.0           AL                   43.1
# 2      Algeria              18.0           DZ                   17.4
#
#    Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0          652230             323000       32.49          93.0
# 1           28748               9000       11.78         355.0
# 2         2381741             317000       24.28         213.0
#
#   Capital/Major City  Co2-Emissions  ... Population  \
# 0              Kabul           8672  ...   38041754
# 1             Tirana           4536  ...    2854191
# 2            Algiers         150006  ...   43053054
#
#    Population: Labor force participation (%) Tax revenue (%)  Total tax rate  \
# 0                                       48.9             9.3            71.4
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110 entries, 0 to 193
# Data columns (total 37 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    110 non-null    object
#  1   Density
# (P/Km2)                            110 non-null    float64
#  2   Abbreviation                               110 non-null    object
#  3   Agricultural Land( %)                      110 non-null    float64
#  4   Land Area(Km2)                             110 non-null    int64
#  5   Armed Forces size                          110 non-null    int64
#  6   Birth Rate                                 110 non-null    float64
#  7   Calling Code                               110 non-null    float64
#  8   Capital/Major City                         110 non-null    object
#  9   Co2-Emissions                              110 non-null    int64
# ...

# %%
object_cols, numerical_cols = separate_object_numerical(data)
print("Object Columns:", object_cols)
print("Numerical Columns:", numerical_cols)
# Out:
# Object Columns: ['Country', 'Abbreviation', 'Capital/Major City', 'CPI', 'Currency-Code', 'Gasoline Price', 'Largest city', 'Official language']
# Numerical Columns: ['Density\n(P/Km2)', 'Agricultural Land( %)', 'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code', 'Co2-Emissions', 'CPI Change (%)', 'Fertility Rate', 'Forested Area (%)', 'GDP', 'Gross primary education enrollment (%)', 'Gross tertiary education enrollment (%)', 'Infant mortality', 'Life expectancy', 'Maternal mortality ratio', 'Minimum wage', 'Out of pocket health expenditure', 'Physicians per thousand', 'Population', 'Population: Labor force participation (%)', 'Tax revenue (%)', 'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude', 'GDP_zscore', 'Log_GDP']

# %%
data[object_cols].head(3)
# data['CPI'] = data['CPI'].astype(float)
# Out:
#        Country Abbreviation Capital/Major City     CPI Currency-Code  \
# 0  Afghanistan           AF              Kabul   149.9           AFN
# 1      Albania           AL             Tirana  119.05           ALL
# 2      Algeria           DZ            Algiers  151.36           DZD
#
#   Gasoline Price Largest city Official language
# 0         $0.70         Kabul            Pashto
# 1         $1.36        Tirana          Albanian
# 2         $0.28       Algiers            Arabic

# %%
data['Gasoline Price'] = data['Gasoline Price'].str.replace('[\$,]', '', regex=True).astype(float)
# data['Forested Area (%)'] = data['Forested Area (%)'].str.replace('[\$,]', '', regex=True).astype(float)
# data['Gross primary education enrollment'] = data['Gross primary education enrollment'].str.replace('[\$,]', '', regex=True).astype(float)
# data['CPI'] = data['CPI'].str.replace('[\$,]', '', regex=True).astype(float)

# %%
data['Gasoline Price']
# Out:
# 0      0.70
# 1      1.36
# 2      0.28
# 4      0.97
# 6      1.10
#        ...
# 185    1.46
# 186    0.71
# 187    1.50
# 191    0.80
# 193    1.40
# Name: Gasoline Price, Length: 110, dtype: float64

# %%
columns = ['CPI','Forested Area (%)','Gross primary education enrollment (%)','Gross tertiary education enrollment (%)' ]
for col in columns:
    data[col] = data[col].apply(lambda x: float(str(x).replace('$', '').replace(',', '')))

# %%
# data['CPI'] = clean_comma_numeric_column(data['CPI'])
# data['Forested Area (%)'] = clean_comma_numeric_column(data['Forested Area (%)'])
# data['Gross primary education enrollment (%)'] = clean_comma_numeric_column(data['Gross primary education enrollment (%)'])
# data['Gross tertiary education enrollment (%)'] = clean_comma_numeric_column(data['Gross tertiary education enrollment (%)'])

# %%
from sklearn.preprocessing import LabelEncoder

def encode_categorical_features(data):
    le = LabelEncoder()
    categorical_columns = data.select_dtypes(include=['object']).columns
    
    for col in categorical_columns:
        data[col] = le.fit_transform(data[col])
    
    return data

# %%
encoded_df = encode_categorical_features(data)

# %%
encoded_df
# Out:
#      Country  Density\n(P/Km2)  Abbreviation  Agricultural Land( %)  \
# 0          0              60.0             0                   58.1
# 1          1             105.0             1                   43.1
# 2          2              18.0            28                   17.4
# 4          3              26.0             3                   47.5
# 6          4              17.0             4                   54.3
# ..       ...               ...           ...                    ...
# 185      105             281.0            34                   71.7
# 186      106              36.0           106                   44.4
# 187      107              20.0           107                   82.6
# 191      108             314.0           108                   39.3
# 193      109              25.0           109                   32.1
#
#      Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0            652230             323000       32.49          93.0
# ...

# %%
encoded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 110 entries, 0 to 193
# Data columns (total 37 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Country                                    110 non-null    int64
#  1   Density
# (P/Km2)                            110 non-null    float64
#  2   Abbreviation                               110 non-null    int64
#  3   Agricultural Land( %)                      110 non-null    float64
#  4   Land Area(Km2)                             110 non-null    int64
#  5   Armed Forces size                          110 non-null    int64
#  6   Birth Rate                                 110 non-null    float64
#  7   Calling Code                               110 non-null    float64
#  8   Capital/Major City                         110 non-null    int64
#  9   Co2-Emissions                              110 non-null    int64
# ...

# %%
object_cols, numerical_cols = separate_object_numerical(encoded_df)
print("Object Columns:", object_cols)
print("Numerical Columns:", numerical_cols)
# Out:
# Object Columns: []
# Numerical Columns: ['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)', 'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code', 'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)', 'Currency-Code', 'Fertility Rate', 'Forested Area (%)', 'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)', 'Gross tertiary education enrollment (%)', 'Infant mortality', 'Largest city', 'Life expectancy', 'Maternal mortality ratio', 'Minimum wage', 'Official language', 'Out of pocket health expenditure', 'Physicians per thousand', 'Population', 'Population: Labor force participation (%)', 'Tax revenue (%)', 'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude', 'GDP_zscore', 'Log_GDP']

# %%
encoded_df.columns
# Out:
# Index(['Country', 'Density\n(P/Km2)', 'Abbreviation', 'Agricultural Land( %)',
#        'Land Area(Km2)', 'Armed Forces size', 'Birth Rate', 'Calling Code',
#        'Capital/Major City', 'Co2-Emissions', 'CPI', 'CPI Change (%)',
#        'Currency-Code', 'Fertility Rate', 'Forested Area (%)',
#        'Gasoline Price', 'GDP', 'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude', 'GDP_zscore', 'Log_GDP'],
#       dtype='object')

# %% [markdown]
# #### For Regression:
# 'Life expectancy',
# 'GDP' or 'Log_GDP',
# 'Infant mortality',
# 'Unemployment rate'

# %%
df = encoded_df.copy()

# %%
df.head(12)
# Out:
#     Country  Density\n(P/Km2)  Abbreviation  Agricultural Land( %)  \
# 0         0              60.0             0                   58.1
# 1         1             105.0             1                   43.1
# 2         2              18.0            28                   17.4
# 4         3              26.0             3                   47.5
# 6         4              17.0             4                   54.3
# 7         5             104.0             2                   58.9
# 8         6               3.0             5                   48.2
# 10        7             123.0             6                   57.7
# 13        8            1265.0             8                   70.6
# 14        9             668.0             7                   23.3
# 16       10             383.0             9                   44.6
# 17       11              17.0            15                    7.0
#
#     Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# ...

# %% [markdown]
# ### Let suppose we have target Log_GDP

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance

# Load your dataset
# df = pd.read_csv('your_data.csv')
# Separate features and target variable
X = df.drop(columns=['Log_GDP'])
y = df['Log_GDP']

# %%
X.fillna(X.mean(), inplace=True)

# %%
cor = data.corr()

# %%
cor
# Out:
#                                             Country  Density\n(P/Km2)  \
# Country                                    1.000000         -0.009630
# Density\n(P/Km2)                          -0.009630          1.000000
# Abbreviation                               0.894236         -0.060010
# Agricultural Land( %)                      0.198246          0.082694
# Land Area(Km2)                            -0.061988         -0.173716
# Armed Forces size                          0.022474          0.086431
# Birth Rate                                 0.030479         -0.196099
# Calling Code                              -0.021330          0.068072
# Capital/Major City                        -0.023105         -0.031268
# Co2-Emissions                             -0.012854         -0.000760
# CPI                                        0.143004         -0.068539
# CPI Change (%)                             0.069221         -0.115107
# ...

# %%
cor.to_csv('cor.csv')

# %%
imp_cols = [
    "Urban_population",
    "Urban_population (% of total population)",
    "Population: Labor force participation (%)",
    "Population",
    "GDP_zscore",
    "Population (% of total)",
    "Urban_population (% of total population)",
    "Tax revenue (%)",
    "Tax revenue (% of GDP)",
    "Out of pocket health expenditure",
    "Tax revenue",
    "Physicians per thousand",
    "Maternal mortality ratio",
    "Unemployment rate",
    "Log_GDP"
    
]

# %%
data[imp_cols]
